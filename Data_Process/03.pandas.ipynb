# %% [markdown]
# # Pandas

# %% [markdown]
# [pandas](https://pandas.pydata.org/)

# %% [markdown]
# ![pandas](https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F99298F365B1A19AF0A)

# %% [markdown]
# ![dataframe](https://cdncontribute.geeksforgeeks.org/wp-content/uploads/finallpandas.png)

# %%
# 데이터가 (5,3)이면 샘플이 5개이고 피쳐가 3개라고 생각해야함.(엑셀처럼...)
#!pip install pandas

# %%
import pandas as pd
pd.__version__
# Out:
# '1.4.3'

# %%
sr1 = pd.Series([3,2,3,5,7,2,5], name="apple")
sr2 = pd.Series([4,7,9,2,0,5,8], name="banana")
sr3 = pd.Series([4,7,9,2,0,5,8], name="mango", index=["A", "B", "C", "D", "E", "F", "G"])
type(sr1)
# Out:
# pandas.core.series.Series

# %%
sr1
# Out:
# 0    3
# 1    2
# 2    3
# 3    5
# 4    7
# 5    2
# 6    5
# Name: apple, dtype: int64

# %%
sr3
# Out:
# A    4
# B    7
# C    9
# D    2
# E    0
# F    5
# G    8
# Name: mango, dtype: int64

# %%
df = pd.concat([sr1,sr2], axis=1)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#    apple  banana
# 0      3       4
# 1      2       7
# 2      3       9
# 3      5       2
# 4      7       0
# 5      2       5
# 6      5       8

# %%
pd.concat([sr1, sr3], axis=1)
#index가 달라서 이상하게 결합됨
# Out:
#    apple  mango
# 0    3.0    NaN
# 1    2.0    NaN
# 2    3.0    NaN
# 3    5.0    NaN
# 4    7.0    NaN
# 5    2.0    NaN
# 6    5.0    NaN
# A    NaN    4.0
# B    NaN    7.0
# C    NaN    9.0
# D    NaN    2.0
# E    NaN    0.0
# F    NaN    5.0
# G    NaN    8.0

# %%
data = [
    ['John', 'Tom', 'Alice'],
    [3,4,5],
    [True, False, True]
]

pd.DataFrame(data).transpose()
#pd.DataFrame(data).T로 해줘도 같다.
# Out:
#        0  1      2
# 0   John  3   True
# 1    Tom  4  False
# 2  Alice  5   True

# %%
data = {
    'name':['John', 'Tom', 'Alice'],
    'point':[3,5,4],
    'pass':[False, True, False]
}

df = pd.DataFrame(data)
df
# Out:
#     name  point   pass
# 0   John      3  False
# 1    Tom      5   True
# 2  Alice      4  False

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
#피쳐들
# Out:
# Index(['name', 'point', 'pass'], dtype='object')

# %%
data = [
    ['John', 'Tom', 'Alice'],
    [3,4,5],
    [True, False, True]
]

df_x = pd.DataFrame(data).transpose()
df_x.columns = ['Name', 'Points', 'Pass']
df_x
# Out:
#     Name Points   Pass
# 0   John      3   True
# 1    Tom      4  False
# 2  Alice      5   True

# %%
df_x = df_x.rename(columns={'Points':'Score'})
df_x
#column의 하나만을 바꾸고 싶을 때 사용
# Out:
#     Name Score   Pass
# 0   John     3   True
# 1    Tom     4  False
# 2  Alice     5   True

# %%
titanic = pd.read_csv("datasets/titanic_dataset.csv")
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
titanic.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sr = titanic.isna().sum(axis=0)
#값이 비어있는지 확인, True=1, False=0

# %%
type(sr)
# Out:
# pandas.core.series.Series

# %%
import matplotlib.pyplot as plt

plt.bar(sr.index, sr.values)
# Out:
# <BarContainer object of 12 artists>

# %%
sr.index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sr.values
# Out:
# array([  0,   0,   0,   0,   0, 177,   0,   0,   0,   0, 687,   2],
#       dtype=int64)

# %%
#원합 인코딩(머신러닝을 돌릴 때 모두 숫자 데이터로 넣어야 하는데 혈액형의 경우 A,B,AB,O형을 각각
#0,1,2,3이라고 넣었을 때 3을 가지는 데이터가 더 좋은 값이라고 생각하고 학습할 수 있으므로
#이러한 것을 방지하기 위해 하는 인코딩

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
titanic.Embarked.unique()
#위와 같음
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
pd.get_dummies(titanic["Embarked"])
#원합 인코딩 방법
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
#여러 컬럼을 지정하고 싶을 때 리스트 형태로 가지고 옴
titanic[["Embarked", "Pclass"]]
#DataFrame Type(대괄호 2개)
# Out:
#     Embarked  Pclass
# 0          S       3
# 1          C       1
# 2          S       3
# 3          S       1
# 4          S       3
# ..       ...     ...
# 886        S       2
# 887        S       1
# 888        S       3
# 889        C       1
# 890        Q       3
#
# [891 rows x 2 columns]

# %%
titanic["Embarked"]
#Series Type(대괄호 1개)
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
# iloc (숫자만 이용해서 데이터 가져옴)
# loc (이걸 더 많이 씀, 조건을 줄 수 있기 때문에)

# %%
titanic.iloc[0:5,0:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry

# %%
titanic.loc[titanic["Embarked"]=='C',:]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.loc[(titanic["Embarked"]=='C') & (titanic["Survived"]==1),:]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 31            32         1       1
# 36            37         1       3
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 36                                    Mamee, Mr. Hanna    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[0:1]
#범위 지정해서 샘플 가져오기
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
titanic[["Embarked"]]
# Out:
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 1 columns]

# %%
titanic.sort_index(axis=0, ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 890          891         0       3
# 889          890         1       1
# 888          889         0       3
# 887          888         1       1
# 886          887         0       2
# ..           ...       ...     ...
# 4              5         0       3
# 3              4         1       1
# 2              3         1       3
# 1              2         1       1
# 0              1         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 890                                Dooley, Mr. Patrick    male  32.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.sort_values(by=["Age", "Fare"])
#Age 먼저 sorting 후 Fare sorting
# Out:
#      PassengerId  Survived  Pclass  \
# 803          804         1       3
# 755          756         1       2
# 469          470         1       3
# 644          645         1       3
# 831          832         1       2
# ..           ...       ...     ...
# 306          307         1       1
# 334          335         1       1
# 31            32         1       1
# 527          528         0       1
# 557          558         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 803                    Thomas, Master. Assad Alexander    male  0.42      0
# 755                          Hamalainen, Master. Viljo    male  0.67      1
# 469                      Baclini, Miss. Helene Barbara  female  0.75      2
# 644                             Baclini, Miss. Eugenie  female  0.75      2
# 831                    Richards, Master. George Sibley    male  0.83      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#컬럼 추가

# %%
titanic["FamilySize"] = titanic["SibSp"] + titanic["Parch"]
titanic.head()
#컬럼 추가 후 필요 없는 컬럼은 없애면 됨
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\myml\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\envs\myml\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\myml\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SibSp'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#컬럼 없애기
titanic = titanic.drop(["SibSp", "Parch"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [64], in <cell line: 2>()
#       1 #컬럼 없애기
# ----> 2 titanic = titanic.drop(["SibSp", "Parch"], axis=1)
#       3 titanic()
#
# File ~\anaconda3\envs\myml\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\myml\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
# ...

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
#titanic.fillna() --> nan을 0으로 채움

# %%
titanic.loc[titanic["Age"] < 1.0, :]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 831          832         1       2  Richards, Master. George Sibley    male
#
#       Age  Ticket      Fare    Cabin Embarked  FamilySize
# 78   0.83  248738   29.0000      NaN        S           2
# 305  0.92  113781  151.5500  C22 C26        S           3
# 469  0.75    2666   19.2583      NaN        C           3
# 644  0.75    2666   19.2583      NaN        C           3
# 755  0.67  250649   14.5000      NaN        S           2
# ...

# %%
titanic.loc[titanic["Age"] < 1.0, "Cabin"] = "None"
#어느 컬럼을 잡아서 값을 바꾸어줄 때 사용(이상치 작업 할 때 사용)

# %%
titanic.loc[titanic["Age"] < 1.0, "Cabin"]
# Out:
# 78     None
# 305    None
# 469    None
# 644    None
# 755    None
# 803    None
# 831    None
# Name: Cabin, dtype: object

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   Ticket       891 non-null    object
#  7   Fare         891 non-null    float64
#  8   Cabin        210 non-null    object
#  9   Embarked     889 non-null    object
#  10  FamilySize   891 non-null    int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
df = titanic.select_dtypes(include = ["float64"])
#number는 숫자 컬럼을 다 가져오라는 뜻
#float64로 하면 그 데이터 타입만 가져온다는 뜻

# %%
def f1(x):
    print(type(x))
    return x.max() - x.min()

# %%
df.apply(f1)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# Age      79.5800
# Fare    512.3292
# dtype: float64

# %%
df1 = titanic.select_dtypes(include = ["number"])
df1
# Out:
#      PassengerId  Survived  Pclass   Age     Fare  FamilySize
# 0              1         0       3  22.0   7.2500           1
# 1              2         1       1  38.0  71.2833           1
# 2              3         1       3  26.0   7.9250           0
# 3              4         1       1  35.0  53.1000           1
# 4              5         0       3  35.0   8.0500           0
# ..           ...       ...     ...   ...      ...         ...
# 886          887         0       2  27.0  13.0000           0
# 887          888         1       1  19.0  30.0000           0
# 888          889         0       3   NaN  23.4500           3
# 889          890         1       1  26.0  30.0000           0
# 890          891         0       3  32.0   7.7500           0
#
# [891 rows x 6 columns]

# %%
df1.apply(f1)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# PassengerId    890.0000
# Survived         1.0000
# Pclass           2.0000
# Age             79.5800
# Fare           512.3292
# FamilySize      10.0000
# dtype: float64

# %%
def f2(x):
    if x > 30:
        return 1
    else:
        return 0

# %%
df["Age2"] = df["Age"].apply(f2)
df
# Out:
#       Age     Fare  Age2
# 0    22.0   7.2500     0
# 1    38.0  71.2833     1
# 2    26.0   7.9250     0
# 3    35.0  53.1000     1
# 4    35.0   8.0500     1
# ..    ...      ...   ...
# 886  27.0  13.0000     0
# 887  19.0  30.0000     0
# 888   NaN  23.4500     0
# 889  26.0  30.0000     0
# 890  32.0   7.7500     1
#
# [891 rows x 3 columns]

# %%
def f3(x):
    if x == "male":
        return 1
    else:
        return 0

# %%
titanic.Sex = titanic.Sex.apply(f3)

# %%
titanic.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1     lost       3
# 1            2     lost       1
# 2            3     lost       3
# 3            4     lost       1
# 4            5     lost       3
#
#                                                 Name  Sex   Age  \
# 0                            Braund, Mr. Owen Harris    1  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 2                             Heikkinen, Miss. Laina    0  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 4                           Allen, Mr. William Henry    1  35.0
#
#              Ticket     Fare Cabin Embarked  FamilySize
# 0         A/5 21171   7.2500   NaN        S           1
# 1          PC 17599  71.2833   C85        C           1
# 2  STON/O2. 3101282   7.9250   NaN        S           0
# 3            113803  53.1000  C123        S           1
# 4            373450   8.0500   NaN        S           0

# %%
titanic["Survived"] = titanic["Survived"].apply(lambda x : 'saved' if x == 1 else 'lost')
#숫자를 문자형으로 바꿈

# %%
titanic["Survived"]
# Out:
# 0       lost
# 1      saved
# 2      saved
# 3      saved
# 4       lost
#        ...
# 886     lost
# 887    saved
# 888     lost
# 889    saved
# 890     lost
# Name: Survived, Length: 891, dtype: object

# %%
titanic["Survived"] = titanic["Survived"].map({"saved":0, "lost":1})
titanic.head()
#다시 문자를 숫자로 바꾸기(여러 방법 중 하나)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         1       3
# 1            2         0       1
# 2            3         0       3
# 3            4         0       1
# 4            5         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.isnull().sum(axis=0)
#isna()랑 같음
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
x = titanic.dropna()
x.shape
#na가 하나라도 있는 컬럼이 날라감
# Out:
# (183, 12)

# %%
x = titanic.fillna(0)
x.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500     0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250     0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500     0        S

# %%
titanic["Age"].mean()
# Out:
# 29.69911764705882

# %%
titanic["Age"] = titanic["Age"].fillna(titanic["Age"].mean())
# Age의 값이 비어있는 곳을 평균값으로 채움

# %%
titanic["Age"]
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
titanic["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic["Embarked"] = titanic["Embarked"].fillna("S")

# %%
titanic["Embarked"].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic.isnull().sum(axis=0)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
titanic.drop(["Cabin"], axis=1, inplace=True)
#결측치가 너무 많아서 Cabin 컬럼을 지움

# %%
titanic.isnull().sum(axis=0)
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
import matplotlib.pyplot as plt
sr = titanic["Embarked"].value_counts()
plt.bar(sr.index, sr.values)
plt.show()

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
# 남성, 여성 승객의 나이 평균

# %%
titanic.groupby('Sex').Age.mean()
# Out:
# Sex
# 0    28.216730
# 1    30.505824
# Name: Age, dtype: float64

# %%
titanic.groupby('Sex').Survived.mean()
# Out:
# Sex
# 0    0.742038
# 1    0.188908
# Name: Survived, dtype: float64

# %%
titanic.groupby('Pclass').Survived.mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
#GroupBy

# %%
data = {
    'city' : ['Busan','Busan','Busan','Busan','Seoul','Seoul','Seoul'],
    'fruit' : ['Apple', 'Orange', 'Banana', 'Banana', 'Apple', 'Apple', 'Banana'],
    'price' : [100, 200, 250, 300, 150, 200, 400],
    'quantity' : [1,2,3,4,5,6,7]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#     city   fruit  price  quantity
# 0  Busan   Apple    100         1
# 1  Busan  Orange    200         2
# 2  Busan  Banana    250         3
# 3  Busan  Banana    300         4
# 4  Seoul   Apple    150         5
# 5  Seoul   Apple    200         6
# 6  Seoul  Banana    400         7

# %%
df.groupby('city').price.mean()
# Out:
# city
# Busan    212.5
# Seoul    250.0
# Name: price, dtype: float64

# %%
df.groupby(['city', 'fruit']).price.mean()
# Out:
# city   fruit
# Busan  Apple     100.0
#        Banana    275.0
#        Orange    200.0
# Seoul  Apple     175.0
#        Banana    400.0
# Name: price, dtype: float64

# %%
# 연속형 데이터를 범주형으로 변경

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
titanic['AgeClass'] = pd.cut(titanic['Age'], 3, labels = ['child', 'young', 'old'])

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked AgeClass
# 0         A/5 21171   7.2500        S    child
# 1          PC 17599  71.2833        C    young
# 2  STON/O2. 3101282   7.9250        S    child
# 3            113803  53.1000        S    young
# 4            373450   8.0500        S    young

# %%
titanic['AgeClass'].value_counts()
# Out:
# young    522
# child    319
# old       50
# Name: AgeClass, dtype: int64

# %%
titanic = titanic.drop(["Age"], axis = 1)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0      1      0
# 2                             Heikkinen, Miss. Laina    0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0      1      0
# 4                           Allen, Mr. William Henry    1      0      0
#
#              Ticket     Fare Embarked AgeClass
# 0         A/5 21171   7.2500        S    child
# 1          PC 17599  71.2833        C    young
# 2  STON/O2. 3101282   7.9250        S    child
# 3            113803  53.1000        S    young
# 4            373450   8.0500        S    young

# %%
## 문자열 처리

# %%
import numpy as np

data = {
    'Dave' : 'dave@gmail.com',
    'Steve' : 'steve@naver.com',
    'Rob' : 'rob@gmail.com',
    'wes' : 'wes'
}
sr = pd.Series(data)
sr
# Out:
# Dave      dave@gmail.com
# Steve    steve@naver.com
# Rob        rob@gmail.com
# wes                  wes
# dtype: object

# %%
sr.values
# Out:
# array(['dave@gmail.com', 'steve@naver.com', 'rob@gmail.com', 'wes'],
#       dtype=object)

# %%
sr.str.contains('gmail')
#gmail의 string을 가지고 있는 것을 찾음
# Out:
# Dave      True
# Steve    False
# Rob       True
# wes      False
# dtype: bool

# %%
sr.str.findall('gmail')
# Out:
# Dave     [gmail]
# Steve         []
# Rob      [gmail]
# wes           []
# dtype: object

# %%
# 시계열 데이터

# %%
data = np.random.randn(1000, 3)
data.shape

df = pd.DataFrame(data,
             index=pd.date_range('1/1/2022', periods=1000),
            columns=['A', 'B', 'C'])

df.head(10)
# Out:
#                    A         B         C
# 2022-01-01 -1.626691  0.461888  0.159781
# 2022-01-02 -0.022241 -2.039325 -0.469423
# 2022-01-03  0.560338 -0.527102 -1.024323
# 2022-01-04  0.410205  1.096818  1.166605
# 2022-01-05 -0.887692  2.020875  0.211702
# 2022-01-06 -1.181553  2.219794 -0.153967
# 2022-01-07  0.987522 -0.985774 -0.333590
# 2022-01-08  0.284946  0.150035  0.547798
# 2022-01-09  1.581465 -1.254393  0.477633
# 2022-01-10  0.639510  1.060543  0.095503
